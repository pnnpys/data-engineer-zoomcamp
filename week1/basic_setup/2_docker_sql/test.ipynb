# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time

# %%
import pyarrow.parquet as pq

_file = pq.ParquetFile("yellow_tripdata_2022-01.parquet")
batches = _file.iter_batches(batch_size = 10000) #batches will be a generator

engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# pd.io.sql.get_schema(df, name = "yellow_taxi_data", con=engine)

for data_chunk in batches:

    t_start = time()

    df_chunk = data_chunk.to_pandas()
    df_chunk['tpep_pickup_datetime'] = pd.to_datetime(df_chunk.tpep_pickup_datetime)
    df_chunk['tpep_dropoff_datetime'] = pd.to_datetime(df_chunk.tpep_dropoff_datetime)

    t_end = time()
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

    print('inserted another chunk..., tool %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk..., tool 0.257 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.148 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.140 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.030 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.152 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.028 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.140 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.161 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.026 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.148 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.132 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.167 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.156 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.249 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.165 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.192 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.175 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.150 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.024 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.152 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.026 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.023 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.175 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.192 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.046 second
# inserted another chunk..., tool 0.160 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.022 second
# inserted another chunk..., tool 0.018 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.021 second
# inserted another chunk..., tool 0.019 second
# inserted another chunk..., tool 0.020 second
# inserted another chunk..., tool 0.025 second
# inserted another chunk..., tool 0.021 second
